# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\MLProjects\Back_Order_Prediction\datasets\Kaggle_Training_Dataset_v2.csv")
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_10312\1075672601.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\MLProjects\Back_Order_Prediction\datasets\Kaggle_Training_Dataset_v2.csv")

# %%
df=df.head(10000)
df.columns

# %%
df.plot.scatter(x = df["lead_time"], y = df.columns[-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\MLProjects\Back_Order_Prediction\notebook\Test1.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/MLProjects/Back_Order_Prediction/notebook/Test1.ipynb#ch0000003?line=0'>1</a> df.plot.scatter(x = df["lead_time"], y = df.columns[-1])
#
# File c:\PROGRAMDATA\ANACONDA3\lib\site-packages\pandas\plotting\_core.py:1669, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1586 def scatter(self, x, y, s=None, c=None, **kwargs):
#    1587     """
#    1588     Create a scatter plot with varying marker point size and color.
#    1589
#    (...)
#    1667         ...                       colormap='viridis')
#    1668     """
# -> 1669     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# ...

# %%
columnName=['lead_time', 'forecast_3_month', 'forecast_6_month', 'forecast_9_month',
            'pieces_past_due', 'local_bo_qty']
for i in range(len(columnName)):
    df.plot.scatter(x = columnName[i], y = df.columns[-1])

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.countplot(x='went_on_backorder', data=df)

##for i in range(len(df.columns)-1):
    #sns.countplot(x=df.columns[i], data=df)
# Out:
# <AxesSubplot:xlabel='went_on_backorder', ylabel='count'>

# %%
import matplotlib.pyplot as plt

df.plot(x='national_inv', y=['went_on_backorder'] , kind="bar", figsize=(9, 10))
# Out:
# <AxesSubplot:xlabel='went_on_backorder'>

# %%
'lead_time', 'in_transit_qty',
'forecast_3_month', 'forecast_6_month', 'forecast_9_month',
'sales_1_month', 'sales_3_month', 'sales_6_month', 'sales_9_month',
'min_bank', 'potential_issue', 'pieces_past_due', 'perf_6_month_avg',
'perf_12_month_avg', 'local_bo_qty', 'deck_risk', 'oe_constraint',
'ppap_risk', 'stop_auto_buy', 'rev_stop'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\MLProjects\Back_Order_Prediction\notebook\Test1.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/MLProjects/Back_Order_Prediction/notebook/Test1.ipynb#ch0000007?line=0'>1</a> mp.show()
#
# NameError: name 'mp' is not defined
